# %%
import pandas as pd
import numpy as np
import re

# %%
df = pd.read_csv('cars.csv', low_memory=False)

# %%
columns_to_drop = [
    'Fuel consumption (economy) - combined', 
    'Fuel consumption (economy) - combined (CLTC)', 
    'Fuel consumption (economy) - combined (CNG)', 
    'Fuel consumption (economy) - combined (CNG) (NEDC)', 
    'Fuel consumption (economy) - combined (CNG) (NEDC, WLTP equivalent)', 
    'Fuel consumption (economy) - combined (EPA)', 
    'Fuel consumption (economy) - combined (Ethanol - E85)', 
    'Fuel consumption (economy) - combined (Ethanol - E85) (NEDC)', 
    'Fuel consumption (economy) - combined (LPG)', 
    'Fuel consumption (economy) - combined (LPG) (NEDC)', 
    'Fuel consumption (economy) - combined (LPG) (NEDC, WLTP equivalent)', 
    'Fuel consumption (economy) - combined (NEDC)', 
    'Fuel consumption (economy) - combined (NEDC, WLTP equivalent)', 
    'Fuel consumption (economy) - combined (WLTC)',
    'Acceleration 0 - 62 mph',
    'Acceleration 0 - 200 km/h',
    'Acceleration 0 - 300 km/h',
    'Acceleration 0 - 60 mph',
    'Acceleration 0 - 60 mph (Calculated by Auto-Data.net)',
    'Engine oil specification',
    '200 km/h - 0',
    'Combined fuel consumption (WLTP)', 
    'Combined fuel consumption (WLTP) (CNG)', 
    'Combined fuel consumption (WLTP) (LPG)'
]

df = df.drop(columns_to_drop, axis=1, errors='ignore')

# %%
print(sorted(list(df.columns)))
# Out:
# ['100 km/h - 0', 'Acceleration 0 - 100 km/h', 'Acceleration 0 - 100 km/h (CNG)', 'Acceleration 0 - 100 km/h (Ethanol - E100)', 'Acceleration 0 - 100 km/h (Ethanol - E85)', 'Acceleration 0 - 100 km/h (LPG)', 'AdBlue tank', 'All-electric range', 'All-electric range (CLTC)', 'All-electric range (EPA)', 'All-electric range (NEDC)', 'All-electric range (NEDC, WLTP equivalent)', 'All-electric range (WLTC)', 'All-electric range (WLTP)', 'Approach angle', 'Assisting systems', 'Average Energy consumption', 'Average Energy consumption (CLTC)', 'Average Energy consumption (EPA)', 'Average Energy consumption (NEDC)', 'Average Energy consumption (NEDC, WLTP equivalent)', 'Average Energy consumption (WLTC)', 'Average Energy consumption (WLTP)', 'Battery location', 'Battery technology', 'Battery voltage', 'Battery weight', 'Body type', 'Brand', 'CNG cylinder capacity', 'CO emissions', 'CO emissions (CNG)', 'CO emissions (CNG) (NEDC)', 'CO emissions (CNG) (NEDC, WLTP equivalent)', 'CO emissions (CNG) (WLTP)', 'CO emissions (EPA)', 'CO emissions (Ethanol - E100)', 'CO emissions (Ethanol - E85)', 'CO emissions (Ethanol - E85) (NEDC)', 'CO emissions (LPG)', 'CO emissions (LPG) (NEDC)', 'CO emissions (LPG) (NEDC, WLTP equivalent)', 'CO emissions (LPG) (WLTP)', 'CO emissions (NEDC)', 'CO emissions (NEDC, WLTP equivalent)', 'CO emissions (WLTC)', 'CO emissions (WLTP)', 'Climb angle', 'Compression ratio', 'Coolant', 'Cylinder Bore', 'Departure angle', 'Doors', 'Drag coefficient (C)', 'Drive wheel', 'Drivetrain Architecture', 'Emission standard', 'End of production', 'Engine Model/Code', 'Engine aspiration', 'Engine configuration', 'Engine displacement', 'Engine layout', 'Engine oil capacity', 'Engine systems', 'Front brakes', 'Front overhang', 'Front suspension', 'Front track', 'Fuel Type', 'Fuel consumption (economy) - extra urban', 'Fuel consumption (economy) - extra urban (CNG)', 'Fuel consumption (economy) - extra urban (CNG) (NEDC)', 'Fuel consumption (economy) - extra urban (CNG) (NEDC, WLTP equivalent)', 'Fuel consumption (economy) - extra urban (EPA)', 'Fuel consumption (economy) - extra urban (Ethanol - E100)', 'Fuel consumption (economy) - extra urban (Ethanol - E85)', 'Fuel consumption (economy) - extra urban (Ethanol - E85) (NEDC)', 'Fuel consumption (economy) - extra urban (LPG)', 'Fuel consumption (economy) - extra urban (LPG) (NEDC)', 'Fuel consumption (economy) - extra urban (LPG) (NEDC, WLTP equivalent)', 'Fuel consumption (economy) - extra urban (NEDC)', 'Fuel consumption (economy) - extra urban (NEDC, WLTP equivalent)', 'Fuel consumption (economy) - extra urban (WLTC)', 'Fuel consumption (economy) - urban', 'Fuel consumption (economy) - urban (CNG)', 'Fuel consumption (economy) - urban (CNG) (NEDC)', 'Fuel consumption (economy) - urban (CNG) (NEDC, WLTP equivalent)', 'Fuel consumption (economy) - urban (EPA)', 'Fuel consumption (economy) - urban (Ethanol - E100)', 'Fuel consumption (economy) - urban (Ethanol - E85)', 'Fuel consumption (economy) - urban (Ethanol - E85) (NEDC)', 'Fuel consumption (economy) - urban (LPG)', 'Fuel consumption (economy) - urban (LPG) (NEDC)', 'Fuel consumption (economy) - urban (LPG) (NEDC, WLTP equivalent)', 'Fuel consumption (economy) - urban (NEDC)', 'Fuel consumption (economy) - urban (NEDC, WLTP equivalent)', 'Fuel consumption (economy) - urban (WLTC)', 'Fuel consumption at Low speed (WLTP)', 'Fuel consumption at Low speed (WLTP) (CNG)', 'Fuel consumption at Low speed (WLTP) (LPG)', 'Fuel consumption at Medium speed (WLTP)', 'Fuel consumption at Medium speed (WLTP) (CNG)', 'Fuel consumption at Medium speed (WLTP) (LPG)', 'Fuel consumption at high speed (WLTP)', 'Fuel consumption at high speed (WLTP) (CNG)', 'Fuel consumption at high speed (WLTP) (LPG)', 'Fuel consumption at very high speed (WLTP)', 'Fuel consumption at very high speed (WLTP) (CNG)', 'Fuel consumption at very high speed (WLTP) (LPG)', 'Fuel injection system', 'Fuel tank capacity', 'Fuel tank capacity (LPG)', 'Generation', 'Gross bat ...

# %%
columns = [
    'All-electric range', 
    'All-electric range (CLTC)', 
    'All-electric range (EPA)', 
    'All-electric range (NEDC)', 
    'All-electric range (NEDC, WLTP equivalent)', 
    'All-electric range (WLTC)', 
    'All-electric range (WLTP)'
]

def parse_number_or_range(val, hmean=False):
    """
    Parse a number or range from a string, ignoring units at the end.
    Returns the arithmetic mean if a range, or the number itself.
    """
    if pd.isna(val):
        return np.nan
    
    s = str(val).strip().lower()
    
    # Single regex to capture:
    #  - optional leading spaces
    #  - first number (integer or decimal)
    #  - optional range separator and second number
    #  - ignore any text after numbers (units)
    match = re.match(r"^\s*(\d+(?:\.\d+)?)\s*(?:[-–]\s*(\d+(?:\.\d+)?))?", s)
    if match:
        num1 = float(match.group(1))
        num2 = match.group(2)
        if num2:
            num2 = float(num2)
            if hmean:
                return 2.0 * num1 * num2 / (num1+num2)
            else:
                return (num1 + num2) / 2  # arithmetic mean of range
        else:
            return num1
    
    return np.nan


def parse_range(val):
    if pd.isna(val):
        return np.nan
    
    # Remove "km", spaces, etc.
    s = str(val).lower().replace("km", "").strip()
    
    # Match range: e.g. "285-310" or "285 – 310"
    match = re.match(r"^\s*(\d+)\s*[-–]\s*(\d+)\s*$", s)
    if match:
        a, b = map(float, match.groups())
        return (a + b) / 2
    
    # Match single number
    match = re.match(r"^\s*(\d+)\s*$", s)
    if match:
        return float(match.group(1))
    
    return np.nan

data = df[columns].map(parse_number_or_range)
df["All-electric range (avg)"] = data.mean(axis=1)
df = df.drop(columns, axis=1)
#data[data[columns].notna().sum(axis=1)>=2]
df[df["All-electric range (avg)"].notna()]
# Out:
#          Brand   Model                            Generation  \
# 8          BYD      e6                                    e6
# 9          BYD      e2                                    e2
# 10         BYD      e2                                    e2
# 17         BYD      e2                                    e2
# 21         BYD    ETP3                                  ETP3
# ...        ...     ...                                   ...
# 49634  Renault  Twingo            Twingo III (facelift 2019)
# 50014  Renault  Megane  Megane IV (Phase II, 2020) Grandtour
# 50031  Renault  Megane              Megane V E-Tech Electric
# 50059  Renault  Megane              Megane V E-Tech Electric
# 50079  Renault  Megane              Megane V E-Tech Electric
#
#         Start of production End of production  \
# 8                 2017 year               NaN
# 9      September, 2019 year  April, 2021 year
# 10     September, 2019 year  April, 2021 year
# 17         April, 2021 year               NaN
# 21       October, 2023 year               NaN
# ...                     ...               ...
# 49634     August, 2020 year   July, 2024 year
# 50014      April, 2020 year   July, 2023 year
# 50031   February, 2022 year               NaN
# 50059   February, 2022 year               NaN
# 50079   February, 2022 year               NaN
#
#                               Modification (Engine)  \
# 8                      80 kWh (122 Hp) 4WD Electric
# 9                              47.3 kWh (95 Hp) BEV
# 10                             35.2 kWh (95 Hp) BEV
# 17                             33.2 kWh (95 Hp) BEV
# 21                       44.9 kWh (136 Hp) Electric
# ...                                             ...
# 49634                           Z.E. 22 kWh (82 Hp)
# 50014  1.6 E-TECH (158 Hp) Plug-in Hybrid Multimode
# 50031                                 EV40 (130 Hp)
# 50059                                 EV60 (220 Hp)
# 50079                                 EV60 (130 Hp)
#
#                       Powertrain Architecture               Body type  \
# 8                      BEV (Electric Vehicle)                     MPV
# 9                      BEV (Electric Vehicle)               Hatchback
# 10                     BEV (Electric Vehicle)               Hatchback
# 17                     BEV (Electric Vehicle)               Hatchback
# 21                     BEV (Electric Vehicle)                     Van
# ...                                       ...                     ...
# 49634                  BEV (Electric Vehicle)               Hatchback
# 50014  PHEV (Plug-in Hybrid Electric Vehicle)  Station wagon (estate)
# 50031                  BEV (Electric Vehicle)               Hatchback
# 50059                  BEV (Electric Vehicle)               Hatchback
# 50079                  BEV (Electric Vehicle)               Hatchback
#
#                   Fuel Type Max. weight  ... Drag coefficient (C) Doors  \
# 8               Electricity         NaN  ...                  NaN     5
# 9               Electricity         NaN  ...                  NaN     5
# 10              Electricity         NaN  ...                  NaN     5
# 17              Electricity         NaN  ...                  NaN     5
# 21              Electricity     2420 kg  ...                  NaN     5
# ...                     ...         ...  ...                  ...   ...
# 49634           Electricity     1518 kg  ...                  NaN     5
# 50014  Petrol / electricity     2131 kg  ...                  NaN     5
# 50031           Electricity     2045 kg  ...                  NaN     5
# 50059           Electricity     2158 kg  ...                  NaN     5
# 50079           Electricity     2116 kg  ...                  NaN     5
#
#       Engine displacement Acceleration 0 - 100 km/h (CNG)  \
# 8                     NaN                             NaN
# 9                     NaN                             NaN
# 10                    NaN                             NaN
# 17                    NaN                             NaN
# 21                    NaN                             NaN
# ...                   ...                             ...
# 49634                 NaN                             NaN
# 50014             1598 cm                             NaN
# 50031                 NaN                             NaN
# 50059                 NaN                             NaN
# 50079                 NaN                             NaN
#
#                 System torque Torque (Ethanol - E85)  \
# 8                         NaN                    NaN
# 9                      180 Nm                    NaN
# 10                     180 Nm                    NaN
# 17                     180 Nm                    NaN
# 21                     180 Nm                    NaN
# ...                       ...                    ...
# 49634  160 Nm @ 500-3590 rpm.                    NaN
# 50014                     NaN                    NaN
# 50031                  250 Nm                    NaN
# 50059                  300 Nm                    NaN
# 50079                  250 Nm                    NaN
#
#       Number of valves per cylinder  \
# 8                               NaN
# 9                               NaN
# 10                              NaN
# 17                              NaN
# 21                              NaN
# ...                             ...
# 49634                           NaN
# 50014                           4.0
# 50031                           NaN
# 50059                           NaN
# 50079                           NaN
#
#       Fuel consumption (economy) - urban (Ethanol - E85)  \
# 8                                                    NaN
# 9                                                    NaN
# 10                                                   NaN
# 17                                                   NaN
# 21                                                   NaN
# ...                                                  ...
# 49634                                                NaN
# 50014                                                NaN
# 50031                                                NaN
# 50059                                                NaN
# 50079                                                NaN
#
#       Fuel consumption (economy) - extra urban (Ethanol - E85) (NEDC)  \
# 8                                                    NaN
# 9                                                    NaN
# 10                                                   NaN
# 17                                                   NaN
# 21                                                   NaN
# ...                                                  ...
# 49634                                                NaN
# 50014                                                NaN
# 50031                                                NaN
# 50059                                                NaN
# 50079                                                NaN
#
#       All-electric range (avg)
# 8                        400.0
# 9                        405.0
# 10                       305.0
# 17                       301.0
# 21                       233.0
# ...                        ...
# 49634                    180.0
# 50014                     50.0
# 50031                    300.0
# 50059                    470.0
# 50079                    470.0
#
# [1850 rows x 175 columns]

# %%
columns = [
    'Average Energy consumption', 
    'Average Energy consumption (CLTC)', 
    'Average Energy consumption (EPA)', 
    'Average Energy consumption (NEDC)', 
    'Average Energy consumption (NEDC, WLTP equivalent)', 
    'Average Energy consumption (WLTC)', 
    'Average Energy consumption (WLTP)'
]
data = df[columns].map(lambda x: parse_number_or_range(x, hmean=True))
data = data.replace(0, np.nan)
df["Average Energy consumption (kWh/100km)"] = len(data.columns) / (1 / data).sum(axis=1, skipna=True)
df = df.drop(columns, axis=1)
#data[data[columns].notna().any(axis=1)][columns]
#df[df[columns].notna().any(axis=1)][columns]

# %%
df[df['Average Energy consumption (kWh/100km)'].notna()]
# Out:
#          Brand   Model                Generation  Start of production  \
# 0       Alpina      B9            B9 Coupe (E24)            1982 year
# 1       Alpina     B11                 B11 (E32)            1987 year
# 2       Alpina      B9                  B9 (E28)            1981 year
# 3       Alpina     B11                 B11 (E32)            1987 year
# 4       Alpina      C2           C2 Cabrio (E30)  February, 1986 year
# ...        ...     ...                       ...                  ...
# 50079  Renault  Megane  Megane V E-Tech Electric  February, 2022 year
# 50080  Renault  Megane                 Megane IV            2016 year
# 50081  Renault  Megane                 Megane IV            2016 year
# 50082  Renault  Megane                 Megane IV            2016 year
# 50083  Renault  Megane                 Megane IV            2018 year
#
#       End of production     Modification (Engine)     Powertrain Architecture  \
# 0             1985 year              3.5 (245 Hp)  Internal Combustion engine
# 1             1987 year              3.5 (250 Hp)  Internal Combustion engine
# 2             1985 year              3.0 (245 Hp)  Internal Combustion engine
# 3             1993 year              3.5 (254 Hp)  Internal Combustion engine
# 4       July, 1987 year              2.7 (209 Hp)  Internal Combustion engine
# ...                 ...                       ...                         ...
# 50079               NaN             EV60 (130 Hp)      BEV (Electric Vehicle)
# 50080         2018 year   1.2 Energy TCe (100 Hp)  Internal Combustion engine
# 50081         2017 year    1.5 Energy dCi (90 Hp)  Internal Combustion engine
# 50082         2018 year   1.2 Energy TCe (130 Hp)  Internal Combustion engine
# 50083         2020 year  1.3 TCe (160 Hp) EDC FAP  Internal Combustion engine
#
#        Body type          Fuel Type Max. weight  ... Doors  \
# 0          Coupe  Petrol (Gasoline)         NaN  ...   NaN
# 1          Sedan  Petrol (Gasoline)         NaN  ...   NaN
# 2          Sedan  Petrol (Gasoline)         NaN  ...   NaN
# 3          Sedan  Petrol (Gasoline)         NaN  ...   NaN
# 4      Cabriolet  Petrol (Gasoline)         NaN  ...     2
# ...          ...                ...         ...  ...   ...
# 50079  Hatchback        Electricity     2116 kg  ...     5
# 50080  Hatchback  Petrol (Gasoline)     1806 kg  ...     5
# 50081  Hatchback             Diesel     1841 kg  ...     5
# 50082  Hatchback  Petrol (Gasoline)     1806 kg  ...     5
# 50083  Hatchback  Petrol (Gasoline)     1839 kg  ...     5
#
#       Engine displacement Acceleration 0 - 100 km/h (CNG) System torque  \
# 0                     NaN                             NaN           NaN
# 1                     NaN                             NaN           NaN
# 2                     NaN                             NaN           NaN
# 3                     NaN                             NaN           NaN
# 4                 2693 cm                             NaN           NaN
# ...                   ...                             ...           ...
# 50079                 NaN                             NaN        250 Nm
# 50080             1198 cm                             NaN           NaN
# 50081             1461 cm                             NaN           NaN
# 50082             1198 cm                             NaN           NaN
# 50083             1332 cm                             NaN           NaN
#
#       Torque (Ethanol - E85) Number of valves per cylinder  \
# 0                        NaN                           NaN
# 1                        NaN                           NaN
# 2                        NaN                           NaN
# 3                        NaN                           NaN
# 4                        NaN                           NaN
# ...                      ...                           ...
# 50079                    NaN                           NaN
# 50080                    NaN                           4.0
# 50081                    NaN                           2.0
# 50082                    NaN                           4.0
# 50083                    NaN                           4.0
#
#       Fuel consumption (economy) - urban (Ethanol - E85)  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 50079                                                NaN
# 50080                                                NaN
# 50081                                                NaN
# 50082                                                NaN
# 50083                                                NaN
#
#       Fuel consumption (economy) - extra urban (Ethanol - E85) (NEDC)  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 50079                                                NaN
# 50080                                                NaN
# 50081                                                NaN
# 50082                                                NaN
# 50083                                                NaN
#
#       All-electric range (avg) Average Energy consumption (kWh/100km)
# 0                          NaN                                    inf
# 1                          NaN                                    inf
# 2                          NaN                                    inf
# 3                          NaN                                    inf
# 4                          NaN                                    inf
# ...                        ...                                    ...
# 50079                    470.0                                  108.5
# 50080                      NaN                                    inf
# 50081                      NaN                                    inf
# 50082                      NaN                                    inf
# 50083                      NaN                                    inf
#
# [50084 rows x 169 columns]

# %%
extra_urban_fuel_cols = [
    'Fuel consumption (economy) - extra urban', 
    'Fuel consumption (economy) - extra urban (EPA)', 
    'Fuel consumption (economy) - extra urban (NEDC)', 
    'Fuel consumption (economy) - extra urban (NEDC, WLTP equivalent)', 
    'Fuel consumption (economy) - extra urban (WLTC)', 
]

extra_urban_cng_cols = [
    'Fuel consumption (economy) - extra urban (CNG)', 
    'Fuel consumption (economy) - extra urban (CNG) (NEDC)', 
    'Fuel consumption (economy) - extra urban (CNG) (NEDC, WLTP equivalent)', 
]

extra_urban_lpg_cols = [
    'Fuel consumption (economy) - extra urban (LPG)', 
    'Fuel consumption (economy) - extra urban (LPG) (NEDC)', 
    'Fuel consumption (economy) - extra urban (LPG) (NEDC, WLTP equivalent)', 
]

extra_urban_ethanol_cols = [
    'Fuel consumption (economy) - extra urban (Ethanol - E100)', 
    'Fuel consumption (economy) - extra urban (Ethanol - E85)', 
    'Fuel consumption (economy) - extra urban (Ethanol - E85) (NEDC)', 
]

urban_fuel_cols = [
    'Fuel consumption (economy) - urban', 
    'Fuel consumption (economy) - urban (EPA)', 
    'Fuel consumption (economy) - urban (NEDC)', 
    'Fuel consumption (economy) - urban (NEDC, WLTP equivalent)', 
    'Fuel consumption (economy) - urban (WLTC)', 
]

urban_cng_cols = [
    'Fuel consumption (economy) - urban (CNG)', 
    'Fuel consumption (economy) - urban (CNG) (NEDC)', 
    'Fuel consumption (economy) - urban (CNG) (NEDC, WLTP equivalent)', 
]

urban_lpg_cols = [
    'Fuel consumption (economy) - urban (LPG)', 
    'Fuel consumption (economy) - urban (LPG) (NEDC)', 
    'Fuel consumption (economy) - urban (LPG) (NEDC, WLTP equivalent)', 
]

urban_ethanol_cols = [
    'Fuel consumption (economy) - urban (Ethanol - E100)', 
    'Fuel consumption (economy) - urban (Ethanol - E85)', 
    'Fuel consumption (economy) - urban (Ethanol - E85) (NEDC)', 
]

fuel_columns = [
    'Fuel consumption (economy) - extra urban', 
    'Fuel consumption (economy) - extra urban (CNG)', 
    'Fuel consumption (economy) - extra urban (CNG) (NEDC)', 
    'Fuel consumption (economy) - extra urban (CNG) (NEDC, WLTP equivalent)', 
    'Fuel consumption (economy) - extra urban (EPA)', 
    'Fuel consumption (economy) - extra urban (Ethanol - E100)', 
    'Fuel consumption (economy) - extra urban (Ethanol - E85)', 
    'Fuel consumption (economy) - extra urban (Ethanol - E85) (NEDC)', 
    'Fuel consumption (economy) - extra urban (LPG)', 
    'Fuel consumption (economy) - extra urban (LPG) (NEDC)', 
    'Fuel consumption (economy) - extra urban (LPG) (NEDC, WLTP equivalent)', 
    'Fuel consumption (economy) - extra urban (NEDC)', 
    'Fuel consumption (economy) - extra urban (NEDC, WLTP equivalent)', 
    'Fuel consumption (economy) - extra urban (WLTC)', 
    'Fuel consumption (economy) - urban', 
    'Fuel consumption (economy) - urban (CNG)', 
    'Fuel consumption (economy) - urban (CNG) (NEDC)', 
    'Fuel consumption (economy) - urban (CNG) (NEDC, WLTP equivalent)', 
    'Fuel consumption (economy) - urban (EPA)', 
    'Fuel consumption (economy) - urban (Ethanol - E100)', 
    'Fuel consumption (economy) - urban (Ethanol - E85)', 
    'Fuel consumption (economy) - urban (Ethanol - E85) (NEDC)', 
    'Fuel consumption (economy) - urban (LPG)', 
    'Fuel consumption (economy) - urban (LPG) (NEDC)', 
    'Fuel consumption (economy) - urban (LPG) (NEDC, WLTP equivalent)', 
    'Fuel consumption (economy) - urban (NEDC)', 
    'Fuel consumption (economy) - urban (NEDC, WLTP equivalent)', 
    'Fuel consumption (economy) - urban (WLTC)', 
    'Fuel consumption at Low speed (WLTP)', 
    'Fuel consumption at Low speed (WLTP) (CNG)', 
    'Fuel consumption at Low speed (WLTP) (LPG)', 
    'Fuel consumption at Medium speed (WLTP)', 
    'Fuel consumption at Medium speed (WLTP) (CNG)', 
    'Fuel consumption at Medium speed (WLTP) (LPG)', 
    'Fuel consumption at high speed (WLTP)', 
    'Fuel consumption at high speed (WLTP) (CNG)', 
    'Fuel consumption at high speed (WLTP) (LPG)', 
    'Fuel consumption at very high speed (WLTP)', 
    'Fuel consumption at very high speed (WLTP) (CNG)', 
    'Fuel consumption at very high speed (WLTP) (LPG)'
]

def parse_fuel_value_hmean(s):
    if pd.isna(s):
        return np.nan
    # Extract all numbers in the string
    numbers = re.findall(r"\d+\.\d+|\d+", s)
    numbers = [float(n) for n in numbers]
    if len(numbers) == 0:
        return np.nan
    # If multiple numbers, take harmonic mean
    if len(numbers) == 1:
        return numbers[0]
    else:
        return len(numbers) / sum(1/n for n in numbers)

df[fuel_columns] = df[fuel_columns].map(parse_fuel_value_hmean)

# %%
# Out:
#          Brand   Model       Generation  Start of production  \
# 4       Alpina      C2  C2 Cabrio (E30)  February, 1986 year
# 11         BYD      F6               F6            2007 year
# 12         BYD      F6               F6            2007 year
# 16      Alpina      C1         C1 (E21)            1980 year
# 23      Alpina     B12  B12 Coupe (E31)            1990 year
# ...        ...     ...              ...                  ...
# 50076  Renault  Megane        Megane IV            2018 year
# 50077  Renault  Megane        Megane IV            2016 year
# 50080  Renault  Megane        Megane IV            2016 year
# 50081  Renault  Megane        Megane IV            2016 year
# 50082  Renault  Megane        Megane IV            2016 year
#
#       End of production    Modification (Engine)     Powertrain Architecture  \
# 4       July, 1987 year             2.7 (209 Hp)  Internal Combustion engine
# 11            2012 year             2.0 (140 Hp)  Internal Combustion engine
# 12            2012 year             2.4 (165 Hp)  Internal Combustion engine
# 16            1983 year             2.3 (170 Hp)  Internal Combustion engine
# 23            1994 year       5.0 i V12 (350 Hp)  Internal Combustion engine
# ...                 ...                      ...                         ...
# 50076         2020 year     1.3 TCe (160 Hp) FAP  Internal Combustion engine
# 50077         2018 year  1.6 Energy dCi (130 Hp)  Internal Combustion engine
# 50080         2018 year  1.2 Energy TCe (100 Hp)  Internal Combustion engine
# 50081         2017 year   1.5 Energy dCi (90 Hp)  Internal Combustion engine
# 50082         2018 year  1.2 Energy TCe (130 Hp)  Internal Combustion engine
#
#        Body type          Fuel Type Max. weight   Length    Width   Height  \
# 4      Cabriolet  Petrol (Gasoline)         NaN      NaN      NaN      NaN
# 11         Sedan  Petrol (Gasoline)         NaN  4846 mm  1822 mm  1465 mm
# 12         Sedan  Petrol (Gasoline)         NaN  4850 mm  1822 mm  1465 mm
# 16         Coupe  Petrol (Gasoline)         NaN      NaN      NaN      NaN
# 23         Coupe  Petrol (Gasoline)     2260 kg  4780 mm  1855 mm  1330 mm
# ...          ...                ...         ...      ...      ...      ...
# 50076  Hatchback  Petrol (Gasoline)     1814 kg  4359 mm  1814 mm  1447 mm
# 50077  Hatchback             Diesel     1890 kg  4359 mm  1814 mm  1447 mm
# 50080  Hatchback  Petrol (Gasoline)     1806 kg  4359 mm  1814 mm  1447 mm
# 50081  Hatchback             Diesel     1841 kg  4359 mm  1814 mm  1447 mm
# 50082  Hatchback  Petrol (Gasoline)     1806 kg  4359 mm  1814 mm  1447 mm
#
#        Fuel consumption (economy) - urban (CNG) (NEDC)  \
# 4                                                  NaN
# 11                                                 NaN
# 12                                                 NaN
# 16                                                 NaN
# 23                                                 NaN
# ...                                                ...
# 50076                                              NaN
# 50077                                              NaN
# 50080                                              NaN
# 50081                                              NaN
# 50082                                              NaN
#
#                  Front suspension Battery weight           Engine aspiration  \
# 4                             NaN            NaN  Naturally aspirated engine
# 11     Independent type McPherson            NaN  Naturally aspirated engine
# 12     Independent type McPherson            NaN  Naturally aspirated engine
# 16                            NaN            NaN  Naturally aspirated engine
# 23                    Coil spring            NaN  Naturally aspirated engine
# ...                           ...            ...                         ...
# 50076                         NaN            NaN   Turbocharger, Intercooler
# 50077  Independent type McPherson            NaN   Turbocharger, Intercooler
# 50080  Independent type McPherson            NaN   Turbocharger, Intercooler
# 50081  Independent type McPherson            NaN   Turbocharger, Intercooler
# 50082  Independent type McPherson            NaN   Turbocharger, Intercooler
#
#       Recuperation output Gross battery capacity  \
# 4                     NaN                    NaN
# 11                    NaN                    NaN
# 12                    NaN                    NaN
# 16                    NaN                    NaN
# 23                    NaN                    NaN
# ...                   ...                    ...
# 50076                 NaN                    NaN
# 50077                 NaN                    NaN
# 50080                 NaN                    NaN
# 50081                 NaN                    NaN
# 50082                 NaN                    NaN
#
#        Fuel consumption (economy) - urban (LPG)  \
# 4                                           NaN
# 11                                          NaN
# 12                                          NaN
# 16                                          NaN
# 23                                          NaN
# ...                                         ...
# 50076                                       NaN
# 50077                                       NaN
# 50080                                       NaN
# 50081                                       NaN
# 50082                                       NaN
#
#        Fuel consumption at Low speed (WLTP) (LPG)               Power  \
# 4                                             NaN              209 Hp
# 11                                            NaN  140 Hp @ 6000 rpm.
# 12                                            NaN  165 Hp @ 5000 rpm.
# 16                                            NaN              170 Hp
# 23                                            NaN  350 Hp @ 5300 rpm.
# ...                                           ...                 ...
# 50076                                         NaN  160 Hp @ 5500 rpm.
# 50077                                         NaN  130 Hp @ 4000 rpm.
# 50080                                         NaN  100 Hp @ 4500 rpm.
# 50081                                         NaN   90 Hp @ 4000 rpm.
# 50082                                         NaN  130 Hp @ 5500 rpm.
#
#       Emission standard Compression ratio  \
# 4                   NaN               NaN
# 11               Euro 3               NaN
# 12                  NaN               NaN
# 16                  NaN               NaN
# 23                  NaN             9.5:1
# ...                 ...               ...
# 50076            Euro 6               NaN
# 50077          Euro 6 b               NaN
# 50080            Euro 6               NaN
# 50081          Euro 6 b               NaN
# 50082            Euro 6               NaN
#
#        Fuel consumption at very high speed (WLTP) All-electric range (WLTP)  \
# 4                                             NaN                       NaN
# 11                                            NaN                       NaN
# 12                                            NaN                       NaN
# 16                                            NaN                       NaN
# 23                                            NaN                       NaN
# ...                                           ...                       ...
# 50076                                         NaN                       NaN
# 50077                                         NaN                       NaN
# 50080                                         NaN                       NaN
# 50081                                         NaN                       NaN
# 50082                                         NaN                       NaN
#
#       Permitted trailer load with brakes (12%) Wheelbase  \
# 4                                          NaN       NaN
# 11                                         NaN   2740 mm
# 12                                         NaN   2740 mm
# 16                                         NaN       NaN
# 23                                         NaN   2684 mm
# ...                                        ...       ...
# 50076                                  1650 kg   2669 mm
# 50077                                  1600 kg   2669 mm
# 50080                                  1300 kg   2669 mm
# 50081                                  1300 kg   2669 mm
# 50082                                  1300 kg   2669 mm
#
#       Power per litre (Ethanol - E100) Average Energy consumption (WLTC)  \
# 4                                  NaN                               NaN
# 11                                 NaN                               NaN
# 12                                 NaN                               NaN
# 16                                 NaN                               NaN
# 23                                 NaN                               NaN
# ...                                ...                               ...
# 50076                              NaN                               NaN
# 50077                              NaN                               NaN
# 50080                              NaN                               NaN
# 50081                              NaN                               NaN
# 50082                              NaN                               NaN
#
#       Acceleration 0 - 100 km/h Maximum speed (CNG)  \
# 4                       6.9 sec                 NaN
# 11                          NaN                 NaN
# 12                          NaN                 NaN
# 16                      7.9 sec                 NaN
# 23                      6.8 sec                 NaN
# ...                         ...                 ...
# 50076                     9 sec                 NaN
# 50077                    10 sec                 NaN
# 50080                  12.3 sec                 NaN
# 50081                  13.4 sec                 NaN
# 50082                  10.6 sec                 NaN
#
#       Power per litre (Ethanol - E85) Maximum speed (Ethanol - E100)  \
# 4                                 NaN                            NaN
# 11                                NaN                            NaN
# 12                                NaN                            NaN
# 16                                NaN                            NaN
# 23                                NaN                            NaN
# ...                               ...                            ...
# 50076                             NaN                            NaN
# 50077                             NaN                            NaN
# 50080                             NaN                            NaN
# 50081                             NaN                            NaN
# 50082                             NaN                            NaN
#
#       Ramp-over (brakeover) angle Power (CNG)  \
# 4                             NaN         NaN
# 11                            NaN         NaN
# 12                            NaN         NaN
# 16                            NaN         NaN
# 23                            NaN         NaN
# ...                           ...         ...
# 50076                         NaN         NaN
# 50077                         NaN         NaN
# 50080                         NaN         NaN
# 50081                         NaN         NaN
# 50082                         NaN         NaN
#
#       Combined fuel consumption (WLTP) (CNG) Power (Ethanol - E100)  \
# 4                                        NaN                    NaN
# 11                                       NaN                    NaN
# 12                                       NaN                    NaN
# 16                                       NaN                    NaN
# 23                                       NaN                    NaN
# ...                                      ...                    ...
# 50076                                    NaN                    NaN
# 50077                                    NaN                    NaN
# 50080                                    NaN                    NaN
# 50081                                    NaN                    NaN
# 50082                                    NaN                    NaN
#
#        Fuel consumption (economy) - urban (Ethanol - E100) AdBlue tank  \
# 4                                                    NaN           NaN
# 11                                                   NaN           NaN
# 12                                                   NaN           NaN
# 16                                                   NaN           NaN
# 23                                                   NaN           NaN
# ...                                                  ...           ...
# 50076                                                NaN           NaN
# 50077                                                NaN           NaN
# 50080                                                NaN           NaN
# 50081                                                NaN           NaN
# 50082                                                NaN           NaN
#
#       CNG cylinder capacity CO emissions (LPG) (NEDC, WLTP equivalent)  \
# 4                       NaN                                        NaN
# 11                      NaN                                        NaN
# 12                      NaN                                        NaN
# 16                      NaN                                        NaN
# 23                      NaN                                        NaN
# ...                     ...                                        ...
# 50076                   NaN                                        NaN
# 50077                   NaN                                        NaN
# 50080                   NaN                                        NaN
# 50081                   NaN                                        NaN
# 50082                   NaN                                        NaN
#
#        Fuel consumption (economy) - extra urban (Ethanol - E85)  \
# 4                                                    NaN
# 11                                                   NaN
# 12                                                   NaN
# 16                                                   NaN
# 23                                                   NaN
# ...                                                  ...
# 50076                                                NaN
# 50077                                                NaN
# 50080                                                NaN
# 50081                                                NaN
# 50082                                                NaN
#
#            Weight-to-power ratio Power (LPG)  Number of cylinders  \
# 4                            NaN         NaN                  6.0
# 11     10.3 kg/Hp, 97.6 Hp/tonne         NaN                  4.0
# 12       8.7 kg/Hp, 115 Hp/tonne         NaN                  4.0
# 16                           NaN         NaN                  6.0
# 23     5.1 kg/Hp, 195.5 Hp/tonne         NaN                 12.0
# ...                          ...         ...                  ...
# 50076  7.8 kg/Hp, 127.6 Hp/tonne         NaN                  4.0
# 50077  10.1 kg/Hp, 98.6 Hp/tonne         NaN                  4.0
# 50080    12.1 kg/Hp, 83 Hp/tonne         NaN                  4.0
# 50081  13.4 kg/Hp, 74.7 Hp/tonne         NaN                  4.0
# 50082  9.3 kg/Hp, 107.9 Hp/tonne         NaN                  4.0
#
#       Average Energy consumption (NEDC, WLTP equivalent)  \
# 4                                                    NaN
# 11                                                   NaN
# 12                                                   NaN
# 16                                                   NaN
# 23                                                   NaN
# ...                                                  ...
# 50076                                                NaN
# 50077                                                NaN
# 50080                                                NaN
# 50081                                                NaN
# 50082                                                NaN
#
#       CO emissions (CNG) (WLTP)  \
# 4                           NaN
# 11                          NaN
# 12                          NaN
# 16                          NaN
# 23                          NaN
# ...                         ...
# 50076                       NaN
# 50077                       NaN
# 50080                       NaN
# 50081                       NaN
# 50082                       NaN
#
#                                  Drivetrain Architecture  \
# 4      The Internal combustion engine (ICE) drives pe...
# 11     The Internal combustion engine (ICE) drives th...
# 12     The Internal combustion engine (ICE) drives th...
# 16     The Internal combustion engine (ICE) drives th...
# 23     The Internal combustion engine (ICE) drives th...
# ...                                                  ...
# 50076  The Internal combustion engine (ICE) drives th...
# 50077  The Internal combustion engine (ICE) drives th...
# 50080  The Internal combustion engine (ICE) drives th...
# 50081  The Internal combustion engine (ICE) drives th...
# 50082  The Internal combustion engine (ICE) drives th...
#
#       Permitted trailer load with brakes (8%) Fuel tank capacity (LPG)  \
# 4                                         NaN                      NaN
# 11                                        NaN                      NaN
# 12                                        NaN                      NaN
# 16                                        NaN                      NaN
# 23                                        NaN                      NaN
# ...                                       ...                      ...
# 50076                                     NaN                      NaN
# 50077                                     NaN                      NaN
# 50080                                     NaN                      NaN
# 50081                                     NaN                      NaN
# 50082                                     NaN                      NaN
#
#       Power per litre (CNG)              Torque     Weight-to-torque ratio  \
# 4                       NaN              267 Nm                        NaN
# 11                      NaN  186 Nm @ 4000 rpm.  7.7 kg/Nm, 129.6 Nm/tonne
# 12                      NaN              220 Nm  6.5 kg/Nm, 153.3 Nm/tonne
# 16                      NaN              210 Nm                        NaN
# 23                      NaN  470 Nm @ 4000 rpm.  3.8 kg/Nm, 262.6 Nm/tonne
# ...                     ...                 ...                        ...
# 50076                   NaN  260 Nm @ 1750 rpm.  4.8 kg/Nm, 207.3 Nm/tonne
# 50077                   NaN  320 Nm @ 1750 rpm.  4.1 kg/Nm, 242.8 Nm/tonne
# 50080                   NaN  175 Nm @ 1500 rpm.  6.9 kg/Nm, 145.2 Nm/tonne
# 50081                   NaN  220 Nm @ 1750 rpm.  5.5 kg/Nm, 182.6 Nm/tonne
# 50082                   NaN  205 Nm @ 2000 rpm.  5.9 kg/Nm, 170.1 Nm/tonne
#
#        Fuel consumption (economy) - extra urban (LPG) (NEDC)  \
# 4                                                    NaN
# 11                                                   NaN
# 12                                                   NaN
# 16                                                   NaN
# 23                                                   NaN
# ...                                                  ...
# 50076                                                NaN
# 50077                                                NaN
# 50080                                                NaN
# 50081                                                NaN
# 50082                                                NaN
#
#        Fuel consumption at Medium speed (WLTP) (LPG)  \
# 4                                                NaN
# 11                                               NaN
# 12                                               NaN
# 16                                               NaN
# 23                                               NaN
# ...                                              ...
# 50076                                            NaN
# 50077                                            NaN
# 50080                                            NaN
# 50081                                            NaN
# 50082                                            NaN
#
#        Fuel consumption (economy) - urban (Ethanol - E85) (NEDC) System power  \
# 4                                                    NaN                  NaN
# 11                                                   NaN                  NaN
# 12                                                   NaN                  NaN
# 16                                                   NaN                  NaN
# 23                                                   NaN                  NaN
# ...                                                  ...                  ...
# 50076                                                NaN                  NaN
# 50077                                                NaN                  NaN
# 50080                                                NaN                  NaN
# 50081                                                NaN                  NaN
# 50082                                                NaN                  NaN
#
#       Front track  Fuel consumption at high speed (WLTP) (CNG)  \
# 4             NaN                                          NaN
# 11        1551 mm                                          NaN
# 12        1551 mm                                          NaN
# 16            NaN                                          NaN
# 23        1560 mm                                          NaN
# ...           ...                                          ...
# 50076     1591 mm                                          NaN
# 50077     1591 mm                                          NaN
# 50080     1591 mm                                          NaN
# 50081     1591 mm                                          NaN
# 50082     1591 mm                                          NaN
#
#       Average Energy consumption  \
# 4                            NaN
# 11                           NaN
# 12                           NaN
# 16                           NaN
# 23                           NaN
# ...                          ...
# 50076                        NaN
# 50077                        NaN
# 50080                        NaN
# 50081                        NaN
# 50082                        NaN
#
#        Fuel consumption (economy) - extra urban (NEDC, WLTP equivalent)  \
# 4                                                    NaN
# 11                                                   NaN
# 12                                                   NaN
# 16                                                   NaN
# 23                                                   NaN
# ...                                                  ...
# 50076                                                NaN
# 50077                                                NaN
# 50080                                                NaN
# 50081                                                NaN
# 50082                                                NaN
#
#                Fuel injection system      Engine systems  \
# 4                                NaN                 NaN
# 11     Multi-port manifold injection                 NaN
# 12                  Direct injection                 NaN
# 16                               NaN                 NaN
# 23     Multi-port manifold injection                 NaN
# ...                              ...                 ...
# 50076               Direct injection  Particulate filter
# 50077              Diesel Commonrail  Particulate filter
# 50080               Direct injection                 NaN
# 50081              Diesel Commonrail  Particulate filter
# 50082               Direct injection                 NaN
#
#        Fuel consumption (economy) - urban (LPG) (NEDC, WLTP equivalent)  \
# 4                                                    NaN
# 11                                                   NaN
# 12                                                   NaN
# 16                                                   NaN
# 23                                                   NaN
# ...                                                  ...
# 50076                                                NaN
# 50077                                                NaN
# 50080                                                NaN
# 50081                                                NaN
# 50082                                                NaN
#
#       Battery voltage                Rear suspension Max. roof load  \
# 4                 NaN                            NaN            NaN
# 11                NaN                            NaN            NaN
# 12                NaN                            NaN            NaN
# 16                NaN                            NaN            NaN
# 23                NaN                    Coil spring            NaN
# ...               ...                            ...            ...
# 50076             NaN                            NaN          80 kg
# 50077             NaN  Semi-independent, coil spring            NaN
# 50080             NaN  Semi-independent, coil spring            NaN
# 50081             NaN  Semi-independent, coil spring            NaN
# 50082             NaN  Semi-independent, coil spring            NaN
#
#       Piston Stroke Acceleration 0 - 100 km/h (Ethanol - E85)  \
# 4               NaN                                       NaN
# 11              NaN                                       NaN
# 12              NaN                                       NaN
# 16              NaN                                       NaN
# 23            75 mm                                       NaN
# ...             ...                                       ...
# 50076           NaN                                       NaN
# 50077       79.5 mm                                       NaN
# 50080       73.1 mm                                       NaN
# 50081       80.5 mm                                       NaN
# 50082       73.1 mm                                       NaN
#
#       CO emissions (WLTC) Width including mirrors  \
# 4                     NaN                     NaN
# 11                    NaN                     NaN
# 12                    NaN                     NaN
# 16                    NaN                     NaN
# 23                    NaN                     NaN
# ...                   ...                     ...
# 50076                 NaN                 2058 mm
# 50077                 NaN                 2058 mm
# 50080                 NaN                 2058 mm
# 50081                 NaN                 2058 mm
# 50082                 NaN                 2058 mm
#
#       Combined fuel consumption (WLTP)  \
# 4                                  NaN
# 11                                 NaN
# 12                                 NaN
# 16                                 NaN
# 23                                 NaN
# ...                                ...
# 50076                              NaN
# 50077                              NaN
# 50080                              NaN
# 50081                              NaN
# 50082                              NaN
#
#        Fuel consumption (economy) - extra urban (EPA) Max load Wading depth  \
# 4                                                 NaN      NaN          NaN
# 11                                                NaN      NaN          NaN
# 12                                                NaN      NaN          NaN
# 16                                                NaN      NaN          NaN
# 23                                                NaN   470 kg          NaN
# ...                                               ...      ...          ...
# 50076                                             NaN   560 kg          NaN
# 50077                                             NaN   572 kg          NaN
# 50080                                             NaN   601 kg          NaN
# 50081                                             NaN   636 kg          NaN
# 50082                                             NaN   601 kg          NaN
#
#       100 km/h - 0 Engine configuration               Assisting systems  \
# 4              NaN               Inline                             NaN
# 11             NaN               Inline  ABS (Anti-lock braking system)
# 12             NaN               Inline                             NaN
# 16             NaN                  NaN                             NaN
# 23             NaN             V-engine  ABS (Anti-lock braking system)
# ...            ...                  ...                             ...
# 50076          NaN               Inline  ABS (Anti-lock braking system)
# 50077          NaN               Inline  ABS (Anti-lock braking system)
# 50080          NaN               Inline  ABS (Anti-lock braking system)
# 50081          NaN               Inline  ABS (Anti-lock braking system)
# 50082          NaN               Inline  ABS (Anti-lock braking system)
#
#                  Drive wheel Acceleration 0 - 100 km/h (Ethanol - E100)  \
# 4      All wheel drive (4x4)                                        NaN
# 11         Front wheel drive                                        NaN
# 12         Front wheel drive                                        NaN
# 16          Rear wheel drive                                        NaN
# 23          Rear wheel drive                                        NaN
# ...                      ...                                        ...
# 50076      Front wheel drive                                        NaN
# 50077      Front wheel drive                                        NaN
# 50080      Front wheel drive                                        NaN
# 50081      Front wheel drive                                        NaN
# 50082      Front wheel drive                                        NaN
#
#        Fuel consumption at high speed (WLTP) (LPG) Power per litre (LPG)  \
# 4                                              NaN                   NaN
# 11                                             NaN                   NaN
# 12                                             NaN                   NaN
# 16                                             NaN                   NaN
# 23                                             NaN                   NaN
# ...                                            ...                   ...
# 50076                                          NaN                   NaN
# 50077                                          NaN                   NaN
# 50080                                          NaN                   NaN
# 50081                                          NaN                   NaN
# 50082                                          NaN                   NaN
#
#       Approach angle Fuel tank capacity Rear (Back) track  \
# 4                NaN                NaN               NaN
# 11               NaN                NaN           1551 mm
# 12               NaN                NaN           1551 mm
# 16               NaN                NaN               NaN
# 23               NaN               90 l           1552 mm
# ...              ...                ...               ...
# 50076            NaN               50 l           1586 mm
# 50077            NaN               47 l           1586 mm
# 50080            NaN               47 l           1586 mm
# 50081            NaN               47 l           1586 mm
# 50082            NaN               47 l           1586 mm
#
#        Fuel consumption (economy) - urban (NEDC, WLTP equivalent)  \
# 4                                                    NaN
# 11                                                   NaN
# 12                                                   NaN
# 16                                                   NaN
# 23                                                   NaN
# ...                                                  ...
# 50076                                                NaN
# 50077                                                NaN
# 50080                                                NaN
# 50081                                                NaN
# 50082                                                NaN
#
#                   Steering type  \
# 4                           NaN
# 11     Steering rack and pinion
# 12     Steering rack and pinion
# 16                          NaN
# 23                          NaN
# ...                         ...
# 50076  Steering rack and pinion
# 50077  Steering rack and pinion
# 50080  Steering rack and pinion
# 50081  Steering rack and pinion
# 50082  Steering rack and pinion
#
#        Fuel consumption (economy) - extra urban (Ethanol - E100)  \
# 4                                                    NaN
# 11                                                   NaN
# 12                                                   NaN
# 16                                                   NaN
# 23                                                   NaN
# ...                                                  ...
# 50076                                                NaN
# 50077                                                NaN
# 50080                                                NaN
# 50081                                                NaN
# 50082                                                NaN
#
#        Fuel consumption (economy) - urban (LPG) (NEDC) Maximum speed (LPG)  \
# 4                                                  NaN                 NaN
# 11                                                 NaN                 NaN
# 12                                                 NaN                 NaN
# 16                                                 NaN                 NaN
# 23                                                 NaN                 NaN
# ...                                                ...                 ...
# 50076                                              NaN                 NaN
# 50077                                              NaN                 NaN
# 50080                                              NaN                 NaN
# 50081                                              NaN                 NaN
# 50082                                              NaN                 NaN
#
#        Fuel consumption at high speed (WLTP) Rear overhang  \
# 4                                        NaN           NaN
# 11                                       NaN           NaN
# 12                                       NaN           NaN
# 16                                       NaN           NaN
# 23                                       NaN           NaN
# ...                                      ...           ...
# 50076                                    NaN        771 mm
# 50077                                    NaN        771 mm
# 50080                                    NaN        771 mm
# 50081                                    NaN        771 mm
# 50082                                    NaN        771 mm
#
#        Fuel consumption (economy) - urban (NEDC) CO emissions (WLTP)  \
# 4                                            NaN                 NaN
# 11                                           NaN                 NaN
# 12                                           NaN                 NaN
# 16                                           NaN                 NaN
# 23                                           NaN                 NaN
# ...                                          ...                 ...
# 50076                                        NaN                 NaN
# 50077                                        NaN                 NaN
# 50080                                        NaN                 NaN
# 50081                                        NaN                 NaN
# 50082                                        NaN                 NaN
#
#       All-electric range CO emissions (LPG) (WLTP)  \
# 4                    NaN                       NaN
# 11                   NaN                       NaN
# 12                   NaN                       NaN
# 16                   NaN                       NaN
# 23                   NaN                       NaN
# ...                  ...                       ...
# 50076                NaN                       NaN
# 50077                NaN                       NaN
# 50080                NaN                       NaN
# 50081                NaN                       NaN
# 50082                NaN                       NaN
#
#        Fuel consumption at very high speed (WLTP) (CNG)  \
# 4                                                   NaN
# 11                                                  NaN
# 12                                                  NaN
# 16                                                  NaN
# 23                                                  NaN
# ...                                                 ...
# 50076                                               NaN
# 50077                                               NaN
# 50080                                               NaN
# 50081                                               NaN
# 50082                                               NaN
#
#       Acceleration 0 - 100 km/h (LPG) Front overhang  \
# 4                                 NaN            NaN
# 11                                NaN            NaN
# 12                                NaN            NaN
# 16                                NaN            NaN
# 23                                NaN            NaN
# ...                               ...            ...
# 50076                             NaN         919 mm
# 50077                             NaN         919 mm
# 50080                             NaN         919 mm
# 50081                             NaN         919 mm
# 50082                             NaN         919 mm
#
#        Fuel consumption (economy) - extra urban (LPG)  \
# 4                                                 NaN
# 11                                                NaN
# 12                                                NaN
# 16                                                NaN
# 23                                                NaN
# ...                                               ...
# 50076                                             NaN
# 50077                                             NaN
# 50080                                             NaN
# 50081                                             NaN
# 50082                                             NaN
#
#       Net (usable) battery capacity  Fuel consumption (economy) - urban (EPA)  \
# 4                               NaN                                       NaN
# 11                              NaN                                       NaN
# 12                              NaN                                       NaN
# 16                              NaN                                       NaN
# 23                              NaN                                       NaN
# ...                             ...                                       ...
# 50076                           NaN                                       NaN
# 50077                           NaN                                       NaN
# 50080                           NaN                                       NaN
# 50081                           NaN                                       NaN
# 50082                           NaN                                       NaN
#
#       CO emissions (EPA)        Engine layout CO emissions (CNG)  \
# 4                    NaN  Front, Longitudinal                NaN
# 11                   NaN    Front, Transverse                NaN
# 12                   NaN    Front, Transverse                NaN
# 16                   NaN                  NaN                NaN
# 23                   NaN  Front, Longitudinal                NaN
# ...                  ...                  ...                ...
# 50076                NaN    Front, Transverse                NaN
# 50077                NaN    Front, Transverse                NaN
# 50080                NaN    Front, Transverse                NaN
# 50081                NaN    Front, Transverse                NaN
# 50082                NaN    Front, Transverse                NaN
#
#       CO emissions (CNG) (NEDC)  Fuel consumption (economy) - urban  \
# 4                           NaN                           22.695035
# 11                          NaN                                 NaN
# 12                          NaN                                 NaN
# 16                          NaN                           24.407375
# 23                          NaN                           32.495812
# ...                         ...                                 ...
# 50076                       NaN                           12.909261
# 50077                       NaN                            8.978032
# 50080                       NaN                           13.084112
# 50081                       NaN                            8.061420
# 50082                       NaN                           12.734082
#
#        Fuel consumption (economy) - extra urban (CNG) (NEDC, WLTP equivalent)  \
# 4                                                    NaN
# 11                                                   NaN
# 12                                                   NaN
# 16                                                   NaN
# 23                                                   NaN
# ...                                                  ...
# 50076                                                NaN
# 50077                                                NaN
# 50080                                                NaN
# 50081                                                NaN
# 50082                                                NaN
#
#       All-electric range (CLTC) Trunk (boot) space - maximum  \
# 4                           NaN                          NaN
# 11                          NaN                          NaN
# 12                          NaN                          NaN
# 16                          NaN                          NaN
# 23                          NaN                          NaN
# ...                         ...                          ...
# 50076                       NaN                       1247 l
# 50077                       NaN                       1247 l
# 50080                       NaN                       1247 l
# 50081                       NaN                       1247 l
# 50082                       NaN                       1247 l
#
#        Fuel consumption (economy) - extra urban (CNG)  \
# 4                                                 NaN
# 11                                                NaN
# 12                                                NaN
# 16                                                NaN
# 23                                                NaN
# ...                                               ...
# 50076                                             NaN
# 50077                                             NaN
# 50080                                             NaN
# 50081                                             NaN
# 50082                                             NaN
#
#       All-electric range (EPA) Trunk (boot) space - minimum Engine Model/Code  \
# 4                          NaN                          NaN               NaN
# 11                         NaN                        480 l         BYD 483QB
# 12                         NaN                        450 l   Mitsubishi 4G69
# 16                         NaN                          NaN               NaN
# 23                         NaN                        320 l               NaN
# ...                        ...                          ...               ...
# 50076                      NaN                        407 l           H5H 470
# 50077                      NaN                        384 l               R9M
# 50080                      NaN                        384 l           H5F 408
# 50081                      NaN                        384 l           K9K 656
# 50082                      NaN                        384 l           H5F 408
#
#       CO emissions (NEDC) Torque (CNG)      Power steering Battery location  \
# 4                     NaN          NaN                 NaN              NaN
# 11                    NaN          NaN  Hydraulic Steering              NaN
# 12                    NaN          NaN  Hydraulic Steering              NaN
# 16                    NaN          NaN                 NaN              NaN
# 23                    NaN          NaN  Hydraulic Steering              NaN
# ...                   ...          ...                 ...              ...
# 50076                 NaN          NaN   Electric Steering              NaN
# 50077                 NaN          NaN   Electric Steering              NaN
# 50080                 NaN          NaN   Electric Steering              NaN
# 50081                 NaN          NaN                 NaN              NaN
# 50082                 NaN          NaN   Electric Steering              NaN
#
#       Width with mirrors folded  \
# 4                           NaN
# 11                          NaN
# 12                          NaN
# 16                          NaN
# 23                          NaN
# ...                         ...
# 50076                       NaN
# 50077                       NaN
# 50080                       NaN
# 50081                       NaN
# 50082                       NaN
#
#        Fuel consumption (economy) - urban (CNG) (NEDC, WLTP equivalent)  \
# 4                                                    NaN
# 11                                                   NaN
# ...
# ...                                                  ...          ...
# 50076                                                NaN     125 g/km
# 50077  195/65 R15; 205/55 R16; 205/50 R17; 225/45 R17...     103 g/km
# 50080  195/65 R15; 205/55 R16; 205/50 R17; 225/45 R17...     120 g/km
# 50081  195/65 R15; 205/55 R16; 205/50 R17; 225/45 R17...      95 g/km
# 50082  195/65 R15; 205/55 R16; 205/50 R17; 225/45 R17...     119 g/km
#
#       CO emissions (NEDC, WLTP equivalent) Kerb Weight  \
# 4                                      NaN         NaN
# 11                                     NaN     1435 kg
# 12                                     NaN     1435 kg
# 16                                     NaN         NaN
# 23                                     NaN     1790 kg
# ...                                    ...         ...
# 50076                                  NaN     1254 kg
# 50077                                  NaN     1318 kg
# 50080                                  NaN     1205 kg
# 50081                                  NaN     1205 kg
# 50082                                  NaN     1205 kg
#
#       Maximum speed (Ethanol - E85)  \
# 4                               NaN
# 11                              NaN
# 12                              NaN
# 16                              NaN
# 23                              NaN
# ...                             ...
# 50076                           NaN
# 50077                           NaN
# 50080                           NaN
# 50081                           NaN
# 50082                           NaN
#
#        Fuel consumption (economy) - extra urban (CNG) (NEDC)  \
# 4                                                    NaN
# 11                                                   NaN
# 12                                                   NaN
# 16                                                   NaN
# 23                                                   NaN
# ...                                                  ...
# 50076                                                NaN
# 50077                                                NaN
# 50080                                                NaN
# 50081                                                NaN
# 50082                                                NaN
#
#        Fuel consumption (economy) - extra urban (WLTC)  \
# 4                                                  NaN
# 11                                                 NaN
# 12                                                 NaN
# 16                                                 NaN
# 23                                                 NaN
# ...                                                ...
# 50076                                              NaN
# 50077                                              NaN
# 50080                                              NaN
# 50081                                              NaN
# 50082                                              NaN
#
#       CO emissions (Ethanol - E85)  Fuel consumption at Low speed (WLTP)  \
# 4                              NaN                                   NaN
# 11                             NaN                                   NaN
# 12                             NaN                                   NaN
# 16                             NaN                                   NaN
# 23                             NaN                                   NaN
# ...                            ...                                   ...
# 50076                          NaN                                   NaN
# 50077                          NaN                                   NaN
# 50080                          NaN                                   NaN
# 50081                          NaN                                   NaN
# 50082                          NaN                                   NaN
#
#        Fuel consumption at very high speed (WLTP) (LPG)  \
# 4                                                   NaN
# 11                                                  NaN
# 12                                                  NaN
# 16                                                  NaN
# 23                                                  NaN
# ...                                                 ...
# 50076                                               NaN
# 50077                                               NaN
# 50080                                               NaN
# 50081                                               NaN
# 50082                                               NaN
#
#        Fuel consumption (economy) - urban (CNG)  \
# 4                                           NaN
# 11                                          NaN
# 12                                          NaN
# 16                                          NaN
# 23                                          NaN
# ...                                         ...
# 50076                                       NaN
# 50077                                       NaN
# 50080                                       NaN
# 50081                                       NaN
# 50082                                       NaN
#
#        Fuel consumption at Low speed (WLTP) (CNG)  \
# 4                                             NaN
# 11                                            NaN
# 12                                            NaN
# 16                                            NaN
# 23                                            NaN
# ...                                           ...
# 50076                                         NaN
# 50077                                         NaN
# 50080                                         NaN
# 50081                                         NaN
# 50082                                         NaN
#
#        Fuel consumption at Medium speed (WLTP) (CNG)  \
# 4                                                NaN
# 11                                               NaN
# 12                                               NaN
# 16                                               NaN
# 23                                               NaN
# ...                                              ...
# 50076                                            NaN
# 50077                                            NaN
# 50080                                            NaN
# 50081                                            NaN
# 50082                                            NaN
#
#       Average Energy consumption (CLTC)  \
# 4                                   NaN
# 11                                  NaN
# 12                                  NaN
# 16                                  NaN
# 23                                  NaN
# ...                                 ...
# 50076                               NaN
# 50077                               NaN
# 50080                               NaN
# 50081                               NaN
# 50082                               NaN
#
#       CO emissions (CNG) (NEDC, WLTP equivalent)  \
# 4                                            NaN
# 11                                           NaN
# 12                                           NaN
# 16                                           NaN
# 23                                           NaN
# ...                                          ...
# 50076                                        NaN
# 50077                                        NaN
# 50080                                        NaN
# 50081                                        NaN
# 50082                                        NaN
#
#       Number of gears and type of gearbox CO emissions (LPG) (NEDC)  \
# 4                                     NaN                       NaN
# 11           5 gears, manual transmission                       NaN
# 12           5 gears, manual transmission                       NaN
# 16                                    NaN                       NaN
# 23        4 gears, automatic transmission                       NaN
# ...                                   ...                       ...
# 50076        6 gears, manual transmission                       NaN
# 50077        6 gears, manual transmission                       NaN
# 50080        6 gears, manual transmission                       NaN
# 50081        6 gears, manual transmission                       NaN
# 50082        6 gears, manual transmission                       NaN
#
#       Drag coefficient (C) Doors Engine displacement  \
# 4                      NaN     2             2693 cm
# 11                     NaN     4             1991 cm
# 12                     NaN     4             2378 cm
# 16                     NaN     5             2316 cm
# 23                     NaN     2             4988 cm
# ...                    ...   ...                 ...
# 50076                  NaN     5             1332 cm
# 50077                  NaN     5             1598 cm
# 50080                  NaN     5             1198 cm
# 50081                  NaN     5             1461 cm
# 50082                  NaN     5             1198 cm
#
#       Acceleration 0 - 100 km/h (CNG) System torque Torque (Ethanol - E85)  \
# 4                                 NaN           NaN                    NaN
# 11                                NaN           NaN                    NaN
# 12                                NaN           NaN                    NaN
# 16                                NaN           NaN                    NaN
# 23                                NaN           NaN                    NaN
# ...                               ...           ...                    ...
# 50076                             NaN           NaN                    NaN
# 50077                             NaN           NaN                    NaN
# 50080                             NaN           NaN                    NaN
# 50081                             NaN           NaN                    NaN
# 50082                             NaN           NaN                    NaN
#
#        Number of valves per cylinder  \
# 4                                NaN
# 11                               4.0
# 12                               4.0
# 16                               NaN
# 23                               2.0
# ...                              ...
# 50076                            4.0
# 50077                            4.0
# 50080                            4.0
# 50081                            2.0
# 50082                            4.0
#
#        Fuel consumption (economy) - urban (Ethanol - E85)  \
# 4                                                    NaN
# 11                                                   NaN
# 12                                                   NaN
# 16                                                   NaN
# 23                                                   NaN
# ...                                                  ...
# 50076                                                NaN
# 50077                                                NaN
# 50080                                                NaN
# 50081                                                NaN
# 50082                                                NaN
#
#        Fuel consumption (economy) - extra urban (Ethanol - E85) (NEDC)  \
# 4                                                    NaN
# 11                                                   NaN
# 12                                                   NaN
# 16                                                   NaN
# 23                                                   NaN
# ...                                                  ...
# 50076                                                NaN
# 50077                                                NaN
# 50080                                                NaN
# 50081                                                NaN
# 50082                                                NaN
#
#        All-electric range (avg)  Fuel consumption highway  \
# 4                           NaN                 62.792877
# 11                          NaN                 61.913696
# 12                          NaN                 64.546305
# 16                          NaN                 57.492931
# 23                          NaN                 80.882353
# ...                         ...                       ...
# 50076                       NaN                 43.977055
# 50077                       NaN                 34.749035
# 50080                       NaN                 42.145594
# 50081                       NaN                 32.882012
# 50082                       NaN                 43.062201
#
#        Fuel consumption highway CNG  Fuel consumption highway LPG  \
# 4                               inf                           inf
# 11                              inf                           inf
# 12                              inf                           inf
# 16                              inf                           inf
# 23                              inf                           inf
# ...                             ...                           ...
# 50076                           inf                           inf
# 50077                           inf                           inf
# 50080                           inf                           inf
# 50081                           inf                           inf
# 50082                           inf                           inf
#
#        Fuel consumption highway Ethanol  Fuel consumption city  \
# 4                                   inf             113.475177
# 11                                  inf                    inf
# 12                                  inf                    inf
# 16                                  inf             122.036874
# 23                                  inf             162.479062
# ...                                 ...                    ...
# 50076                               inf              64.546305
# 50077                               inf              44.890162
# 50080                               inf              65.420561
# 50081                               inf              40.307102
# 50082                               inf              63.670412
#
#        Fuel consumption city CNG  Fuel consumption city LPG  \
# 4                            inf                        inf
# 11                           inf                        inf
# 12                           inf                        inf
# 16                           inf                        inf
# 23                           inf                        inf
# ...                          ...                        ...
# 50076                        inf                        inf
# 50077                        inf                        inf
# 50080                        inf                        inf
# 50081                        inf                        inf
# 50082                        inf                        inf
#
#        Fuel consumption city Ethanol
# 4                                inf
# 11                               inf
# 12                               inf
# 16                               inf
# 23                               inf
# ...                              ...
# 50076                            inf
# 50077                            inf
# 50080                            inf
# 50081                            inf
# 50082                            inf
#
# [34239 rows x 194 columns]
